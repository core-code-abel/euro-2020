# %% [markdown]
# # Tabla de Eventos

# %%
import pandas as pd
import json

df = pd.read_csv("./eurocup_2020_results.csv")
df["events_list"][0]
df
# Out:
#                         stage          date   pens pens_home_score  \
# 0                      Final     11.07.2021   True               3
# 1                Semi-finals    07.07.2021   False           False
# 2                Semi-finals     06.07.2021   True               4
# 3             Quarter-finals    03.07.2021   False           False
# 4             Quarter-finals    03.07.2021   False           False
# 5             Quarter-finals    02.07.2021   False           False
# 6             Quarter-finals     02.07.2021   True               1
# 7                Round of 16    29.06.2021   False           False
# 8                Round of 16    29.06.2021   False           False
# 9                Round of 16     28.06.2021   True               4
# 10               Round of 16    28.06.2021   False           False
# 11               Round of 16    27.06.2021   False           False
# 12               Round of 16    27.06.2021   False           False
# ...

# %% [markdown]
# ##  Formato de datos
#
# - event_team [away, home]
# - event_time
# - event_type
# - event_player_1
# - event_player_2 (asistente en goles

# %% [markdown]
# ## Procesado del string
# - Debemos procesar la columna para poder obtener un JSON en cada celda
# - Sustituir \' por "
# - Sustituir " " por "
# - Al pasar a json se produce un error al intentar convertir valores booleanos -> paso a [1, 0]
# - Sustituir dobles comillas en nombres de jugadores.

# %%
import re

def replaceDoubleQuotes(str):
    midQuotes = re.findall(r'\w"\w', str)
    for occurrence in midQuotes:
        str = str.replace(occurrence, occurrence.replace('"', "\'"))
    return str

def process_events(str):
    substitutions = {
        "\'": '"',
        '" "': '"',
        'False': '0',
        'True': '1'
    }
    for k in substitutions:
        str = str.replace(k, substitutions[k])
    return json.loads(replaceDoubleQuotes(str))

event_list = df['events_list'].apply(process_events)
event_list[:5]
# Out:
# 0    [{'event_team': 'away', 'event_time': ' 2', 'e...
# 1    [{'event_team': 'away', 'event_time': ' 30', '...
# 2    [{'event_team': 'away', 'event_time': ' 51', '...
# 3    [{'event_team': 'away', 'event_time': ' 4', 'e...
# 4    [{'event_team': 'away', 'event_time': ' 5', 'e...
# Name: events_list, dtype: object

# %% [markdown]
# ## Limpieza de datos
# - Para los eventos del tipo (PK) vemos que aparecen con datos event_result y event_player
# - Vamos a unificar estos datos sustituyendo PK por PK-GOAL y PK-MISSED
# - El valor de event_player en estos casos irá a action_player_1
# - Event_time se establecerá a 120 (tiempo del final de la prórroga)
# - Event_team almacenará el id del equipo en lugar de home/away. EL valor lo traerá de la tabla teams creada en ***01_matches.ipynb***

# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

load_dotenv()

POSTGRES_USER = os.getenv('POSTGRES_USER')
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')
POSTGRES_HOST = os.getenv('POSTGRES_HOST')
POSTGRES_PORT = os.getenv('POSTGRES_PORT')
POSTGRES_DATABASE = os.getenv('POSTGRES_DATABASE')

url = f'postgresql+psycopg2://{POSTGRES_USER}:{POSTGRES_PASSWORD}@{POSTGRES_HOST}:{POSTGRES_PORT}/{POSTGRES_DATABASE}'
print(url)
engine = create_engine(url)
connection = engine.connect()
# Out:
# postgresql+psycopg2://phqilykoacfdfu:514fa478368ec88d904a7b1dfcdffef80731b9d57a3c48fc196e1a7a868e570e@ec2-52-214-178-113.eu-west-1.compute.amazonaws.com:5432/d8fmf92045q3sr

# %%
events = []

for i, list in enumerate(event_list):
    for event in list:
        event['match_id'] = i + 1
        if event['event_type'] == 'PK':
            event['event_type'] += f"-{event['event_result']}"
            event['action_player_1'] = event['event_player']
            event['event_time'] = 120
        team_name = df.iloc[i]['team_name_home' if event['event_team'] == 'home' else 'team_name_away'].strip()
        event['event_team'] = next(connection.execute(f"SELECT team_id FROM teams WHERE team_name='{team_name}'"))[0]
        print (event['event_team'], team_name, event['action_player_1'])
        events.append(event)

events = pd.DataFrame(events).drop(columns=["event_player", "event_result"])
# Out:
# 2 England  Luke Shaw
# 1 Italy  Nicolo Barella
# 1 Italy  Bryan Cristante
# 1 Italy  Leonardo Bonucci
# 1 Italy  Domenico Berardi
# 1 Italy  Leonardo Bonucci
# 2 England  Bukayo Saka
# 2 England  Jordan Henderson
# 1 Italy  Lorenzo Insigne
# 1 Italy  Federico Bernardeschi
# 1 Italy  Giorgio Chiellini
# 1 Italy  Andrea Belotti
# 1 Italy  Manuel Locatelli
# 2 England  Jack Grealish
# 2 England  Harry Maguire
# 1 Italy  Jorginho
# 1 Italy  Alessandro Florenzi
# 2 England  Marcus Rashford
# 2 England  Jadon Sancho
# 1 Italy  Domenico Berardi
# 2 England  Harry Kane
# 1 Italy  Andrea Belotti
# 2 England  Harry Maguire
# 1 Italy  Leonardo Bonucci
# 2 England  Marcus Rashford
# 1 Italy  Federico Bernardeschi
# 2 England  Jadon Sancho
# 1 Italy  Jorginho
# 2 England  Bukayo Saka
# 3 Denmark  Mikkel Damsgaard
# 2 England  Simon Kjaer
# 2 England  Harry Maguire
# 3 Denmark  Daniel Wass
# 3 Denmark  Yussuf Poulsen
# 3 Denmark  Christian Nørgaard
# 2 England  Jack Grealish
# ...

# %%
events['event_type'].value_counts()
# Out:
# Substitution          454
# Yellow card           150
# Goal                  122
# PK-Goal                24
# PK-Missed              14
# Own goal               11
# Penalty                 9
# Disallowed goal         7
# Red card                5
# Second yellow card      1
# Name: event_type, dtype: int64

# %% [markdown]
# ## Creación de la tabla events

# %%
query = '''
    DROP TABLE IF EXISTS events;
    CREATE TABLE matches (
        match_id SERIAL PRIMARY KEY,
        stage VARCHAR(50) NOT NULL,
        date DATE NOT NULL,
        solve_on_pens BOOLEAN NOT NULL,
        home_match_team_id INTEGER NOT NULL,
        away_match_team_id INTEGER NOT NULL
    );
'''

connection.execute(query)
